# %%
import pandas as pd
import numpy as np
import csv
from sqlalchemy import create_engine

password = "/Users/john/Desktop/FINAL PROJECT Johns File/Jupyter/password.py"
file_dir = '/Users/john/Desktop/'
from password import db_password
import time

# %%
# File to Load (Remember to change the path if needed.)
NYS_county_data_file = "/Users/john/Desktop/Git Repository/COVID_GeoJSON_FinalProject/FINAL PROJECT Johns File/Data/county_data_Portia.csv"

# %%
NYS_county_data = pd.read_csv(NYS_county_data_file)

NYS_county_data
# Out:
#      fips country state              county   level  lat  \
# 0   36001      US    NY       Albany County  county  NaN
# 1   36003      US    NY     Allegany County  county  NaN
# 2   36005      US    NY        Bronx County  county  NaN
# 3   36007      US    NY       Broome County  county  NaN
# 4   36009      US    NY  Cattaraugus County  county  NaN
# ..    ...     ...   ...                 ...     ...  ...
# 57  36115      US    NY   Washington County  county  NaN
# 58  36117      US    NY        Wayne County  county  NaN
# 59  36119      US    NY  Westchester County  county  NaN
# 60  36121      US    NY      Wyoming County  county  NaN
# 61  36123      US    NY        Yates County  county  NaN
#
#                        locationId  long  population  \
# 0   iso1:us#iso2:us-ny#fips:36001   NaN      305506
# 1   iso1:us#iso2:us-ny#fips:36003   NaN       46091
# 2   iso1:us#iso2:us-ny#fips:36005   NaN     1418207
# 3   iso1:us#iso2:us-ny#fips:36007   NaN      190488
# ...

# %%
NYS_county_data_df = pd.DataFrame(NYS_county_data)

# %%
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/Vaccination_db"

# %%
engine = create_engine(db_string)

# %%
NYS_county_data_df.to_sql(name='county_data', con=engine)

# %%
rows_imported = 0
# get the start_time from time.time()
start_time = time.time()
for data in pd.read_csv(f'{file_dir}Git Repository/COVID_GeoJSON_FinalProject/FINAL PROJECT Johns File/Data/county_data_Portia.csv', chunksize=1000000):
    print(f'importing rows {rows_imported} to {rows_imported + len(data)}...', end='')
    data.to_sql(name='county_data', con=engine, if_exists='append')
    rows_imported += len(data)

    # add elapsed time to final print out
    print(f'Done. {time.time() - start_time} total seconds elapsed')
# Out:
# importing rows 0 to 62...Done. 0.0542299747467041 total seconds elapsed
