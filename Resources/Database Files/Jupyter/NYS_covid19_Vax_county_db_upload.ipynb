# %%
import pandas as pd
import numpy as np
import csv
from sqlalchemy import create_engine

password = "/Users/john/Desktop/FINAL PROJECT Johns File/password.py"
file_dir = '/Users/john/Desktop/'
from password import db_password
import time

# %%
# File to Load (Remember to change the path if needed.)
NYS_COVID19_Vax_county_file = "/Users/john/Desktop/FINAL PROJECT Johns File/CDC_NYS_Covid_Vax_County.csv"

# %%
NYS_covid19_Vax_county = pd.read_csv(NYS_COVID19_Vax_county_file)

NYS_covid19_Vax_county
# Out:
#            Date        Recip_County  Series_Complete_Pop_Pct  \
# 0      12/13/20       Albany County                        0
# 1      12/13/20     Allegany County                        0
# 2      12/13/20   Chautauqua County                        0
# 3      12/13/20     Chenango County                        0
# 4      12/13/20      Clinton County                        0
# ...         ...                 ...                      ...
# 20123  10/28/21   Washington County                        1
# 20124  10/28/21        Wayne County                        1
# 20125  10/28/21  Westchester County                        1
# 20126  10/28/21      Wyoming County                        0
# 20127  10/28/21        Yates County                        0
#
#       Series_Complete_Yes Series_Complete_12Plus  \
# 0                       0                      0
# 1                       0                      0
# 2                       0                      0
# ...

# %%
NYS_covid19_Vax_county_df = pd.DataFrame(NYS_covid19_Vax_county)

# %%
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/Vaccination_db"

# %%
engine = create_engine(db_string)

# %%
#NYS_covid19_Vax_county_df.to_sql(name='vaccinations by county', con=engine)

# %%
rows_imported = 0
# get the start_time from time.time()
start_time = time.time()
for data in pd.read_csv(f'{file_dir}FINAL PROJECT Johns File/CDC_NYS_Covid_Vax_County.csv', chunksize=1000000):
    print(f'importing rows {rows_imported} to {rows_imported + len(data)}...', end='')
    data.to_sql(name='vaccinations by county', con=engine, if_exists='append')
    rows_imported += len(data)

    # add elapsed time to final print out
    print(f'Done. {time.time() - start_time} total seconds elapsed')
# Out:
# importing rows 0 to 20128...Done. 1.5648949146270752 total seconds elapsed
