# %%
import pandas as pd
import os

# %%
# File to Load (Remember to change the path if needed.)
NYS_COVID19_Testing_data = "New_York_State_Statewide_COVID-19_Testing.csv"

# %%
# Read CSV into a Pandas DataFrame
NYS_covid19_testing_data_df = pd.read_csv(NYS_COVID19_Testing_data)

NYS_covid19_testing_data_df
# Out:
#         Test Date  County  New Positives  Cumulative Number of Positives  \
# 0      03/01/2020  Albany              0                               0
# 1      03/02/2020  Albany              0                               0
# 2      03/03/2020  Albany              0                               0
# 3      03/04/2020  Albany              0                               0
# 4      03/05/2020  Albany              0                               0
# ...           ...     ...            ...                             ...
# 37195  10/17/2021   Yates             17                            1605
# 37196  10/18/2021   Yates              5                            1610
# 37197  10/19/2021   Yates             21                            1631
# 37198  10/20/2021   Yates             16                            1647
# 37199  10/21/2021   Yates             10                            1657
#
#        Total Number of Tests Performed  Cumulative Number of Tests Performed
# ...

# %%
NYC_covid19_testing_data_df = NYS_covid19_testing_data_df[NYS_covid19_testing_data_df["County"].isin(['Brooklyn', 'New York', 'Kings', 'Queens', 'Richmond'])]

NYC_covid19_testing_data_df.head(2400)
# Out:
#         Test Date    County  New Positives  Cumulative Number of Positives  \
# 13800  03/01/2020     Kings              0                               0
# 13801  03/02/2020     Kings              0                               0
# 13802  03/03/2020     Kings              0                               0
# 13803  03/04/2020     Kings              1                               1
# 13804  03/05/2020     Kings              0                               1
# ...           ...       ...            ...                             ...
# 25795  10/17/2021  Richmond             63                           87712
# 25796  10/18/2021  Richmond             71                           87783
# 25797  10/19/2021  Richmond            108                           87891
# 25798  10/20/2021  Richmond             92                           87983
# 25799  10/21/2021  Richmond             65                           88048
#
# ...

# %%
NYC_covid19_testing_data_df.to_csv('NYC_COVID19_TestingTable',index=False)
