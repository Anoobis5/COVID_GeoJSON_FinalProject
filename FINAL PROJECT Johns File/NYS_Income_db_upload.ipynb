# %%
import pandas as pd
import numpy as np
import csv
from sqlalchemy import create_engine

password = "/Users/john/Desktop/FINAL PROJECT Johns File/password.py"
file_dir = '/Users/john/Desktop/'
from password import db_password
import time

# %%
# File to Load (Remember to change the path if needed.)
NYS_income_file = "/Users/john/Desktop/FINAL PROJECT Johns File/NYSERDA_LMI_Data_for_2013-2015.csv"

# %%
NYS_income = pd.read_csv(NYS_income_file)

NYS_income
# Out:
#        County / County Group Households with Elderly Households with Children  \
# 0                     Albany                      No                       No
# 1                     Albany                     Yes                       No
# 2                     Albany                      No                       No
# 3                     Albany                      No                       No
# 4                     Albany                     Yes                       No
# ...                      ...                     ...                      ...
# 223080           Westchester                     Yes                       No
# 223081           Westchester                      No                       No
# 223082           Westchester                     Yes                       No
# 223083           Westchester                     Yes                      Yes
# 223084           Westchester                      No                      Yes
#
# ...

# %%
NYS_income_df = pd.DataFrame(NYS_income)

# %%
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/Vaccination_db"

# %%
engine = create_engine(db_string)

# %%
NYS_income_df.to_sql(name='NYS_Income', con=engine)

# %%
rows_imported = 0
# get the start_time from time.time()
start_time = time.time()
for data in pd.read_csv(f'{file_dir}FINAL PROJECT Johns File/NYSERDA_LMI_Data_for_2013-2015.csv', chunksize=1000000):
    print(f'importing rows {rows_imported} to {rows_imported + len(data)}...', end='')
    data.to_sql(name='NYS_Income', con=engine, if_exists='append')
    rows_imported += len(data)

    # add elapsed time to final print out
    print(f'Done. {time.time() - start_time} total seconds elapsed')
# Out:
# importing rows 0 to 223085...Done. 10.004076957702637 total seconds elapsed
