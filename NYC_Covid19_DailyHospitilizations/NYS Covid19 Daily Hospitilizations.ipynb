# %%
import pandas as pd

# %%
# File to Load (Remember to change the path if needed.)
NYS_COVID19_DailyHospitalizationSummary_data = "New_York_Forward_COVID-19_Daily_Hospitalization_Summary_by_Region.csv"

NYS_COVID19_DailyHospitalizationSummary_data
# Out:
# 'New_York_Forward_COVID-19_Daily_Hospitalization_Summary_by_Region.csv'

# %%
# Read CSV into a Pandas DataFrame
NYS_covid19_DailyHospitalizationSummary_data_df = pd.read_csv(NYS_COVID19_DailyHospitalizationSummary_data)

NYS_covid19_DailyHospitalizationSummary_data_df
# Out:
#       As of Date            Region  Total Patients Hospitalized  \
# 0     03/26/2020    CAPITAL REGION                           40
# 1     03/26/2020  CENTRAL NEW YORK                           20
# 2     03/26/2020      FINGER LAKES                           39
# 3     03/26/2020       LONG ISLAND                         1082
# 4     03/26/2020        MID-HUDSON                          493
# ...          ...               ...                          ...
# 5755  10/22/2021     MOHAWK VALLEY                          107
# 5756  10/22/2021     NEW YORK CITY                          485
# 5757  10/22/2021     NORTH COUNTRY                           95
# 5758  10/22/2021     SOUTHERN TIER                          172
# 5759  10/22/2021  WESTERN NEW YORK                          201
#
#       Total Patients in ICU
# 0                        13
# 1                         4
# 2                        23
# 3                       303
# 4                       126
# ...

# %%
NYC_covid19_DailyHospitalization_data_df = NYS_covid19_DailyHospitalizationSummary_data_df[NYS_covid19_DailyHospitalizationSummary_data_df["Region"].isin(['NEW YORK CITY'])]

NYC_covid19_DailyHospitalization_data_df.head(15)
# Out:
#      As of Date         Region  Total Patients Hospitalized  \
# 6    03/26/2020  NEW YORK CITY                         4733
# 16   03/27/2020  NEW YORK CITY                         5256
# 26   03/28/2020  NEW YORK CITY                         6002
# 36   03/29/2020  NEW YORK CITY                         6631
# 46   03/30/2020  NEW YORK CITY                         7630
# 56   03/31/2020  NEW YORK CITY                         8403
# 66   04/01/2020  NEW YORK CITY                         9091
# 76   04/02/2020  NEW YORK CITY                         9681
# 86   04/03/2020  NEW YORK CITY                        10370
# 96   04/04/2020  NEW YORK CITY                        10726
# 106  04/05/2020  NEW YORK CITY                        10843
# 116  04/06/2020  NEW YORK CITY                        11301
# 126  04/07/2020  NEW YORK CITY                        11741
# 136  04/08/2020  NEW YORK CITY                        11836
# 146  04/09/2020  NEW YORK CITY                        11962
#
# ...

# %%
NYC_covid19_DailyHospitalization_data_df.to_csv('NYC_COVID19_DailyHospitalizationTable',index=False)
